# %% [markdown]
# #Connect 4 Reinforcement Learning Model

# %%
import numpy as np
import sys
from scipy.signal import convolve2d

ROW_COUNT = 6
COLUMN_COUNT = 7

RED = 1
YELLOW = 0
EMPTY = -1

def create_board():
    board = np.full((ROW_COUNT, COLUMN_COUNT), EMPTY)
    return board

def drop_piece(board, row, col, piece):
    board[row][col] = piece

def is_valid_location(board, col):
    return board[ROW_COUNT - 1][col] == EMPTY

def get_next_open_row(board, col):
    for r in range(ROW_COUNT):
        if board[r][col] == EMPTY:
            return r

def print_board(board):
    display_board = np.where(board == EMPTY, '.', board)
    display_board = np.where(board == RED, '1', display_board)
    display_board = np.where(board == YELLOW, '0', display_board)
    print(np.flip(display_board, 0))

def winning_move(board, piece):
    # Define the kernel to use for convolution
    kernel = np.array([[1, 1, 1, 1]])

    # Check horizontal
    if (convolve2d(board == piece, kernel, mode='valid') == 4).any():
        return True

    # Check vertical
    if (convolve2d(board == piece, kernel.T, mode='valid') == 4).any():
        return True

    # Check positively sloped diagonals
    if (convolve2d(board == piece, np.eye(4), mode='valid') == 4).any():
        return True

    # Check negatively sloped diagonals
    if (convolve2d(board == piece, np.fliplr(np.eye(4)), mode='valid') == 4).any():
        return True

    return False

board = create_board()
print_board(board)
game_over = False
turn = 0

while not game_over:
    if turn == 0:
        col = int(input("Player 1 (Red) Make your Selection (0-6): "))
        piece = RED
    else:
        col = int(input("Player 2 (Yellow) Make your Selection (0-6): "))
        piece = YELLOW

    if is_valid_location(board, col):
        row = get_next_open_row(board, col)
        drop_piece(board, row, col, piece)

        if winning_move(board, piece):
            print_board(board)
            if piece == RED:
                print("Player 1 (Red) wins!!")
            else:
                print("Player 2 (Yellow) wins!!")
            game_over = True

    print_board(board)
    turn += 1
    turn = turn % 2

    if game_over:
        sys.exit()
# Out:
# [['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c51d3b0cedd2> in <cell line: 60>()
#      60 while not game_over:
#      61     if turn == 0:
# ---> 62         col = int(input("Player 1 (Red) Make your Selection (0-6): "))
#      63         piece = RED
#      64     else:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ##Setup

# %%
# Import
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import random
import os
from scipy.signal import convolve2d

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# parameter and function setups for env

ROW_COUNT = 6
COLUMN_COUNT = 7

RED = 1
YELLOW = 0
EMPTY = -1

def create_board():
    board = np.full((ROW_COUNT, COLUMN_COUNT), EMPTY)
    return board

def drop_piece(board, row, col, piece):
    board[row][col] = piece

def is_valid_location(board, col):
    return board[ROW_COUNT - 1][col] == EMPTY

def get_next_open_row(board, col):
    for r in range(ROW_COUNT):
        if board[r][col] == EMPTY:
            return r

def get_valid_actions(board):
    return [col for col in range(COLUMN_COUNT) if is_valid_location(board, col)]

def print_board(board):
    display_board = np.where(board == EMPTY, '.', board)
    display_board = np.where(board == RED, '1', display_board)
    display_board = np.where(board == YELLOW, '0', display_board)
    print(np.flip(display_board, 0))

def winning_move(board, piece):
    # Define the kernel to use for convolution
    kernel = np.array([[1, 1, 1, 1]])

    # Check horizontal
    if (convolve2d(board == piece, kernel, mode='valid') == 4).any():
        return True

    # Check vertical
    if (convolve2d(board == piece, kernel.T, mode='valid') == 4).any():
        return True

    # Check positively sloped diagonals
    if (convolve2d(board == piece, np.eye(4), mode='valid') == 4).any():
        return True

    # Check negatively sloped diagonals
    if (convolve2d(board == piece, np.fliplr(np.eye(4)), mode='valid') == 4).any():
        return True

    return False

# %%
num_episodes = 20000
savePath = "/content/drive/MyDrive/COSMOS 2024/Connect Four/"
os.makedirs(savePath, exist_ok=True)
training_interval = 100
decay_interval = 500

# Q-Network
class QNetwork(nn.Module):
    def __init__(self):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(ROW_COUNT * COLUMN_COUNT, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, COLUMN_COUNT)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Q-Learning Agent
class QLearningAgent:
    def __init__(self, epsilon=0.7, gamma=1, learning_rate=0.01):
        self.q_network = QNetwork()
        self.t_network = QNetwork()
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=learning_rate)
        self.epsilon = epsilon
        self.gamma = gamma

    def get_action(self, state, valid_actions):
        if random.random() > self.epsilon:
            with torch.no_grad():
                state_tensor = torch.FloatTensor(state.flatten()).unsqueeze(0)
                q_values = self.q_network(state_tensor)
                valid_q_values = q_values[0][valid_actions]
                return valid_actions[torch.argmax(valid_q_values).item()]
        else:
            return random.choice(valid_actions)

    def update(self, state, action, reward, next_state, done):
        state_tensor = torch.FloatTensor(state.flatten()).unsqueeze(0)
        next_state_tensor = torch.FloatTensor(next_state.flatten()).unsqueeze(0)
        action_tensor = torch.LongTensor([action])
        reward_tensor = torch.FloatTensor([reward])

        q_values = self.q_network(state_tensor)
        next_q_values = self.t_network(next_state_tensor)

        q_value = q_values.gather(1, action_tensor.unsqueeze(1))
        print(q_value)
        next_q_value = next_q_values.max(1)[0].unsqueeze(1)
        expected_q_value = reward_tensor + (1 - done) * self.gamma * next_q_value

        loss = nn.MSELoss()(q_value, expected_q_value.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_tnet(self):
        self.t_network.load_state_dict(self.q_network.state_dict())

    def save(self, path):
        torch.save({
            'model_state_dict': self.q_network.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'epsilon': self.epsilon,
            'gamma': self.gamma
        }, path)

    def load(self, path):
        if os.path.exists(path):
            checkpoint = torch.load(path)
            self.q_network.load_state_dict(checkpoint['model_state_dict'])
            self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
            self.epsilon = checkpoint['epsilon']
            self.gamma = checkpoint['gamma']
        else:
            print(f"No saved model found at {path}")

    def epsilon_decay(self):
        self.epsilon = max(0.01, self.epsilon * 0.9)

# Training loop
def train(num_episodes):
    agent1 = QLearningAgent()
    agent2 = QLearningAgent()

    for episode in range(num_episodes):
        board = create_board()
        game_over = False
        turn = 0

        while not game_over:
            valid_actions = get_valid_actions(board)

            if turn == 0:
                action = agent1.get_action(board, valid_actions)
                piece = RED
            else:
                action = agent2.get_action(board, valid_actions)
                piece = YELLOW

            row = get_next_open_row(board, action)
            drop_piece(board, row, action, piece)

            reward = 0
            if winning_move(board, piece):
                reward = 1 if turn == 0 else -1
                game_over = True
            elif len(get_valid_actions(board)) == 0:
                game_over = True

            next_state = board.copy()

            if turn == 0:
                agent1.update(board, action, reward, next_state, game_over)
            else:
                agent2.update(board, action, -reward, next_state, game_over)

            board = next_state
            turn = 1 - turn

        if episode % training_interval == 0:
            print(f"Episode {episode} completed")
            agent1.update_tnet()
            agent2.update_tnet()

        if episode % decay_interval == 0:
            agent1.epsilon_decay()
            agent2.epsilon_decay()

    return agent1, agent2

# Train the agents
agent1, agent2 = train(num_episodes)
agent1.save(savePath + "agent1.pth")
agent2.save(savePath + "agent2.pth")

# Replace ^^ with the below lines if loading from save file

# agent1, agent2 = QLearningAgent(), QLearningAgent()
# agent1.load(savePath + "agent1.pth")
# agent2.load(savePath + "agent2.pth")

# Function to play a game using the trained model
def play_game(agent1, agent2):
    board = create_board()
    game_over = False
    turn = 0

    while not game_over:
        valid_actions = get_valid_actions(board)

        if turn == 0:
            action = agent1.get_action(board, valid_actions)
            piece = RED
        else:
            action = agent2.get_action(board, valid_actions)
            piece = YELLOW

        row = get_next_open_row(board, action)
        drop_piece(board, row, action, piece)

        if winning_move(board, piece):
            print_board(board)
            print(f"Player {turn + 1} wins!")
            game_over = True
        elif len(get_valid_actions(board)) == 0:
            print_board(board)
            print("It's a draw!")
            game_over = True

        print_board(board)
        turn = 1 - turn

# Play a game with the trained agents
play_game(agent1, agent2)
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor([[0.9616]], grad_fn=<GatherBackward0>)
# tensor([[1.5438]], grad_fn=<GatherBackward0>)
# tensor([[0.9550]], grad_fn=<GatherBackward0>)
# tensor([[1.5774]], grad_fn=<GatherBackward0>)
# tensor([[0.9622]], grad_fn=<GatherBackward0>)
# tensor([[1.5977]], grad_fn=<GatherBackward0>)
# tensor([[0.9621]], grad_fn=<GatherBackward0>)
# tensor([[1.5437]], grad_fn=<GatherBackward0>)
# tensor([[0.9618]], grad_fn=<GatherBackward0>)
# tensor([[2.0695]], grad_fn=<GatherBackward0>)
# tensor([[0.9581]], grad_fn=<GatherBackward0>)
# tensor([[1.6375]], grad_fn=<GatherBackward0>)
# tensor([[0.9711]], grad_fn=<GatherBackward0>)
# tensor([[1.6427]], grad_fn=<GatherBackward0>)
# tensor([[0.9588]], grad_fn=<GatherBackward0>)
# tensor([[2.0532]], grad_fn=<GatherBackward0>)
# tensor([[0.9418]], grad_fn=<GatherBackward0>)
# tensor([[1.6121]], grad_fn=<GatherBackward0>)
# tensor([[0.9778]], grad_fn=<GatherBackward0>)
# tensor([[1.6128]], grad_fn=<GatherBackward0>)
# tensor([[0.9773]], grad_fn=<GatherBackward0>)
# tensor([[1.5488]], grad_fn=<GatherBackward0>)
# tensor([[0.9744]], grad_fn=<GatherBackward0>)
# tensor([[1.6823]], grad_fn=<GatherBackward0>)
# tensor([[0.9607]], grad_fn=<GatherBackward0>)
# tensor([[2.3996]], grad_fn=<GatherBackward0>)
# tensor([[0.9610]], grad_fn=<GatherBackward0>)
# tensor([[1.6052]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[1.6110]], grad_fn=<GatherBackward0>)
# tensor([[0.9612]], grad_fn=<GatherBackward0>)
# tensor([[2.8737]], grad_fn=<GatherBackward0>)
# tensor([[0.9639]], grad_fn=<GatherBackward0>)
# tensor([[2.2886]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.8404]], grad_fn=<GatherBackward0>)
# tensor([[0.9416]], grad_fn=<GatherBackward0>)
# tensor([[1.9076]], grad_fn=<GatherBackward0>)
# tensor([[0.9700]], grad_fn=<GatherBackward0>)
# tensor([[1.6098]], grad_fn=<GatherBackward0>)
# tensor([[0.9709]], grad_fn=<GatherBackward0>)
# tensor([[1.7125]], grad_fn=<GatherBackward0>)
# tensor([[0.9710]], grad_fn=<GatherBackward0>)
# tensor([[2.6204]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.4476]], grad_fn=<GatherBackward0>)
# tensor([[0.9554]], grad_fn=<GatherBackward0>)
# tensor([[2.3764]], grad_fn=<GatherBackward0>)
# tensor([[0.9767]], grad_fn=<GatherBackward0>)
# tensor([[2.0501]], grad_fn=<GatherBackward0>)
# tensor([[0.9623]], grad_fn=<GatherBackward0>)
# tensor([[1.6142]], grad_fn=<GatherBackward0>)
# tensor([[0.9570]], grad_fn=<GatherBackward0>)
# tensor([[1.7109]], grad_fn=<GatherBackward0>)
# tensor([[0.9777]], grad_fn=<GatherBackward0>)
# tensor([[1.5800]], grad_fn=<GatherBackward0>)
# tensor([[0.9768]], grad_fn=<GatherBackward0>)
# tensor([[1.6161]], grad_fn=<GatherBackward0>)
# tensor([[0.9747]], grad_fn=<GatherBackward0>)
# tensor([[2.6540]], grad_fn=<GatherBackward0>)
# tensor([[0.9747]], grad_fn=<GatherBackward0>)
# tensor([[2.8821]], grad_fn=<GatherBackward0>)
# tensor([[0.9736]], grad_fn=<GatherBackward0>)
# tensor([[1.6190]], grad_fn=<GatherBackward0>)
# tensor([[0.9717]], grad_fn=<GatherBackward0>)
# tensor([[1.7077]], grad_fn=<GatherBackward0>)
# tensor([[0.9655]], grad_fn=<GatherBackward0>)
# tensor([[1.7068]], grad_fn=<GatherBackward0>)
# tensor([[0.9669]], grad_fn=<GatherBackward0>)
# tensor([[1.6188]], grad_fn=<GatherBackward0>)
# tensor([[0.9655]], grad_fn=<GatherBackward0>)
# tensor([[1.7048]], grad_fn=<GatherBackward0>)
# tensor([[0.9573]], grad_fn=<GatherBackward0>)
# tensor([[1.7037]], grad_fn=<GatherBackward0>)
# tensor([[0.9627]], grad_fn=<GatherBackward0>)
# tensor([[1.7025]], grad_fn=<GatherBackward0>)
# tensor([[0.9322]], grad_fn=<GatherBackward0>)
# tensor([[1.8121]], grad_fn=<GatherBackward0>)
# tensor([[0.9581]], grad_fn=<GatherBackward0>)
# tensor([[2.4337]], grad_fn=<GatherBackward0>)
# tensor([[0.9681]], grad_fn=<GatherBackward0>)
# tensor([[2.7607]], grad_fn=<GatherBackward0>)
# tensor([[0.9677]], grad_fn=<GatherBackward0>)
# tensor([[2.2891]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6232]], grad_fn=<GatherBackward0>)
# tensor([[0.9660]], grad_fn=<GatherBackward0>)
# tensor([[1.6282]], grad_fn=<GatherBackward0>)
# tensor([[0.9648]], grad_fn=<GatherBackward0>)
# tensor([[2.8546]], grad_fn=<GatherBackward0>)
# tensor([[0.9506]], grad_fn=<GatherBackward0>)
# tensor([[2.8519]], grad_fn=<GatherBackward0>)
# tensor([[0.9676]], grad_fn=<GatherBackward0>)
# tensor([[2.8484]], grad_fn=<GatherBackward0>)
# tensor([[0.9682]], grad_fn=<GatherBackward0>)
# tensor([[2.3118]], grad_fn=<GatherBackward0>)
# tensor([[0.9682]], grad_fn=<GatherBackward0>)
# tensor([[2.8422]], grad_fn=<GatherBackward0>)
# tensor([[2.3319]], grad_fn=<GatherBackward0>)
# tensor([[0.9677]], grad_fn=<GatherBackward0>)
# tensor([[2.7281]], grad_fn=<GatherBackward0>)
# tensor([[0.9666]], grad_fn=<GatherBackward0>)
# tensor([[2.7295]], grad_fn=<GatherBackward0>)
# tensor([[0.9652]], grad_fn=<GatherBackward0>)
# tensor([[2.7263]], grad_fn=<GatherBackward0>)
# tensor([[0.9662]], grad_fn=<GatherBackward0>)
# tensor([[2.6910]], grad_fn=<GatherBackward0>)
# tensor([[0.9618]], grad_fn=<GatherBackward0>)
# tensor([[1.7402]], grad_fn=<GatherBackward0>)
# tensor([[0.9616]], grad_fn=<GatherBackward0>)
# tensor([[1.6339]], grad_fn=<GatherBackward0>)
# tensor([[0.9678]], grad_fn=<GatherBackward0>)
# tensor([[1.6346]], grad_fn=<GatherBackward0>)
# tensor([[0.9672]], grad_fn=<GatherBackward0>)
# tensor([[1.6355]], grad_fn=<GatherBackward0>)
# tensor([[0.9610]], grad_fn=<GatherBackward0>)
# tensor([[1.6048]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[1.6377]], grad_fn=<GatherBackward0>)
# tensor([[0.9609]], grad_fn=<GatherBackward0>)
# tensor([[1.5882]], grad_fn=<GatherBackward0>)
# tensor([[0.9606]], grad_fn=<GatherBackward0>)
# tensor([[1.5850]], grad_fn=<GatherBackward0>)
# tensor([[0.9606]], grad_fn=<GatherBackward0>)
# tensor([[1.6691]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5866]], grad_fn=<GatherBackward0>)
# tensor([[0.9579]], grad_fn=<GatherBackward0>)
# tensor([[1.6305]], grad_fn=<GatherBackward0>)
# tensor([[2.7627]], grad_fn=<GatherBackward0>)
# tensor([[0.9582]], grad_fn=<GatherBackward0>)
# tensor([[2.4966]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.7716]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.5917]], grad_fn=<GatherBackward0>)
# tensor([[0.9568]], grad_fn=<GatherBackward0>)
# tensor([[1.6376]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6467]], grad_fn=<GatherBackward0>)
# tensor([[0.9595]], grad_fn=<GatherBackward0>)
# tensor([[1.6146]], grad_fn=<GatherBackward0>)
# tensor([[0.9512]], grad_fn=<GatherBackward0>)
# tensor([[1.6480]], grad_fn=<GatherBackward0>)
# tensor([[0.9596]], grad_fn=<GatherBackward0>)
# tensor([[1.6162]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[1.6173]], grad_fn=<GatherBackward0>)
# tensor([[0.9524]], grad_fn=<GatherBackward0>)
# tensor([[1.6501]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6509]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5861]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6485]], grad_fn=<GatherBackward0>)
# tensor([[0.9553]], grad_fn=<GatherBackward0>)
# tensor([[1.6495]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6183]], grad_fn=<GatherBackward0>)
# tensor([[0.9594]], grad_fn=<GatherBackward0>)
# tensor([[1.5959]], grad_fn=<GatherBackward0>)
# tensor([[2.8271]], grad_fn=<GatherBackward0>)
# tensor([[0.9617]], grad_fn=<GatherBackward0>)
# tensor([[2.8285]], grad_fn=<GatherBackward0>)
# tensor([[0.9615]], grad_fn=<GatherBackward0>)
# tensor([[1.5826]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.5714]], grad_fn=<GatherBackward0>)
# tensor([[0.9607]], grad_fn=<GatherBackward0>)
# tensor([[1.6570]], grad_fn=<GatherBackward0>)
# tensor([[0.9566]], grad_fn=<GatherBackward0>)
# tensor([[1.6261]], grad_fn=<GatherBackward0>)
# tensor([[0.9605]], grad_fn=<GatherBackward0>)
# tensor([[1.6579]], grad_fn=<GatherBackward0>)
# tensor([[0.9608]], grad_fn=<GatherBackward0>)
# tensor([[1.5848]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[1.6590]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[2.6240]], grad_fn=<GatherBackward0>)
# tensor([[0.9642]], grad_fn=<GatherBackward0>)
# tensor([[2.8350]], grad_fn=<GatherBackward0>)
# tensor([[0.9666]], grad_fn=<GatherBackward0>)
# tensor([[2.7401]], grad_fn=<GatherBackward0>)
# tensor([[0.9682]], grad_fn=<GatherBackward0>)
# tensor([[2.8364]], grad_fn=<GatherBackward0>)
# tensor([[0.9594]], grad_fn=<GatherBackward0>)
# tensor([[2.1920]], grad_fn=<GatherBackward0>)
# tensor([[0.9699]], grad_fn=<GatherBackward0>)
# tensor([[2.3526]], grad_fn=<GatherBackward0>)
# tensor([[0.9728]], grad_fn=<GatherBackward0>)
# tensor([[1.5915]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6623]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6627]], grad_fn=<GatherBackward0>)
# tensor([[0.9606]], grad_fn=<GatherBackward0>)
# tensor([[1.5442]], grad_fn=<GatherBackward0>)
# tensor([[0.9786]], grad_fn=<GatherBackward0>)
# tensor([[1.6635]], grad_fn=<GatherBackward0>)
# tensor([[0.9784]], grad_fn=<GatherBackward0>)
# tensor([[1.6639]], grad_fn=<GatherBackward0>)
# tensor([[0.9769]], grad_fn=<GatherBackward0>)
# tensor([[1.5977]], grad_fn=<GatherBackward0>)
# tensor([[0.9772]], grad_fn=<GatherBackward0>)
# tensor([[1.6571]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[1.6653]], grad_fn=<GatherBackward0>)
# tensor([[0.9754]], grad_fn=<GatherBackward0>)
# tensor([[1.6657]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6662]], grad_fn=<GatherBackward0>)
# tensor([[0.9719]], grad_fn=<GatherBackward0>)
# tensor([[1.6667]], grad_fn=<GatherBackward0>)
# tensor([[2.2801]], grad_fn=<GatherBackward0>)
# tensor([[0.9695]], grad_fn=<GatherBackward0>)
# tensor([[2.1174]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[2.1683]], grad_fn=<GatherBackward0>)
# tensor([[0.9569]], grad_fn=<GatherBackward0>)
# tensor([[2.1187]], grad_fn=<GatherBackward0>)
# tensor([[0.9607]], grad_fn=<GatherBackward0>)
# tensor([[1.6724]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.7729]], grad_fn=<GatherBackward0>)
# tensor([[0.9605]], grad_fn=<GatherBackward0>)
# tensor([[2.3167]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6393]], grad_fn=<GatherBackward0>)
# tensor([[0.9588]], grad_fn=<GatherBackward0>)
# tensor([[1.6514]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5932]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6257]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6523]], grad_fn=<GatherBackward0>)
# tensor([[0.9604]], grad_fn=<GatherBackward0>)
# tensor([[1.6527]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6533]], grad_fn=<GatherBackward0>)
# tensor([[2.7123]], grad_fn=<GatherBackward0>)
# tensor([[0.9609]], grad_fn=<GatherBackward0>)
# tensor([[2.8196]], grad_fn=<GatherBackward0>)
# tensor([[0.9610]], grad_fn=<GatherBackward0>)
# tensor([[2.8216]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8234]], grad_fn=<GatherBackward0>)
# tensor([[0.9609]], grad_fn=<GatherBackward0>)
# tensor([[2.2640]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.9848]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.1996]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8753]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[1.6113]], grad_fn=<GatherBackward0>)
# tensor([[0.9593]], grad_fn=<GatherBackward0>)
# tensor([[1.6730]], grad_fn=<GatherBackward0>)
# tensor([[0.9443]], grad_fn=<GatherBackward0>)
# tensor([[1.6794]], grad_fn=<GatherBackward0>)
# tensor([[0.9594]], grad_fn=<GatherBackward0>)
# tensor([[1.6006]], grad_fn=<GatherBackward0>)
# tensor([[0.9780]], grad_fn=<GatherBackward0>)
# tensor([[1.6903]], grad_fn=<GatherBackward0>)
# tensor([[0.9787]], grad_fn=<GatherBackward0>)
# tensor([[1.6520]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6523]], grad_fn=<GatherBackward0>)
# tensor([[0.9759]], grad_fn=<GatherBackward0>)
# tensor([[1.6528]], grad_fn=<GatherBackward0>)
# tensor([[0.9729]], grad_fn=<GatherBackward0>)
# tensor([[3.0032]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6273]], grad_fn=<GatherBackward0>)
# tensor([[0.9492]], grad_fn=<GatherBackward0>)
# tensor([[3.0019]], grad_fn=<GatherBackward0>)
# tensor([[0.9604]], grad_fn=<GatherBackward0>)
# tensor([[1.8251]], grad_fn=<GatherBackward0>)
# tensor([[0.9741]], grad_fn=<GatherBackward0>)
# tensor([[1.6886]], grad_fn=<GatherBackward0>)
# tensor([[0.9728]], grad_fn=<GatherBackward0>)
# tensor([[1.6052]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6059]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6641]], grad_fn=<GatherBackward0>)
# tensor([[0.9659]], grad_fn=<GatherBackward0>)
# tensor([[1.6193]], grad_fn=<GatherBackward0>)
# tensor([[0.9634]], grad_fn=<GatherBackward0>)
# tensor([[2.8296]], grad_fn=<GatherBackward0>)
# tensor([[0.9651]], grad_fn=<GatherBackward0>)
# tensor([[2.8262]], grad_fn=<GatherBackward0>)
# tensor([[0.9661]], grad_fn=<GatherBackward0>)
# tensor([[2.7305]], grad_fn=<GatherBackward0>)
# tensor([[0.9664]], grad_fn=<GatherBackward0>)
# tensor([[2.2504]], grad_fn=<GatherBackward0>)
# tensor([[0.9572]], grad_fn=<GatherBackward0>)
# tensor([[1.7102]], grad_fn=<GatherBackward0>)
# tensor([[0.9656]], grad_fn=<GatherBackward0>)
# tensor([[1.6569]], grad_fn=<GatherBackward0>)
# tensor([[2.8018]], grad_fn=<GatherBackward0>)
# tensor([[0.9606]], grad_fn=<GatherBackward0>)
# tensor([[2.7942]], grad_fn=<GatherBackward0>)
# tensor([[0.9590]], grad_fn=<GatherBackward0>)
# tensor([[2.6054]], grad_fn=<GatherBackward0>)
# tensor([[0.9592]], grad_fn=<GatherBackward0>)
# tensor([[2.7823]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.2278]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6257]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[2.7268]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.0938]], grad_fn=<GatherBackward0>)
# tensor([[0.9682]], grad_fn=<GatherBackward0>)
# tensor([[1.6017]], grad_fn=<GatherBackward0>)
# tensor([[0.9703]], grad_fn=<GatherBackward0>)
# tensor([[1.6282]], grad_fn=<GatherBackward0>)
# tensor([[0.9711]], grad_fn=<GatherBackward0>)
# tensor([[1.6291]], grad_fn=<GatherBackward0>)
# tensor([[0.9707]], grad_fn=<GatherBackward0>)
# tensor([[2.5125]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.8627]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5980]], grad_fn=<GatherBackward0>)
# tensor([[0.9781]], grad_fn=<GatherBackward0>)
# tensor([[1.6085]], grad_fn=<GatherBackward0>)
# tensor([[0.9782]], grad_fn=<GatherBackward0>)
# tensor([[1.6344]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[1.6142]], grad_fn=<GatherBackward0>)
# tensor([[0.9746]], grad_fn=<GatherBackward0>)
# tensor([[1.6136]], grad_fn=<GatherBackward0>)
# tensor([[0.9715]], grad_fn=<GatherBackward0>)
# tensor([[2.5382]], grad_fn=<GatherBackward0>)
# tensor([[0.9718]], grad_fn=<GatherBackward0>)
# tensor([[2.6424]], grad_fn=<GatherBackward0>)
# tensor([[0.9708]], grad_fn=<GatherBackward0>)
# tensor([[1.6173]], grad_fn=<GatherBackward0>)
# tensor([[0.9688]], grad_fn=<GatherBackward0>)
# tensor([[1.6398]], grad_fn=<GatherBackward0>)
# tensor([[0.9660]], grad_fn=<GatherBackward0>)
# tensor([[2.5848]], grad_fn=<GatherBackward0>)
# tensor([[0.9672]], grad_fn=<GatherBackward0>)
# tensor([[1.6115]], grad_fn=<GatherBackward0>)
# tensor([[0.9674]], grad_fn=<GatherBackward0>)
# tensor([[1.6423]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.6439]], grad_fn=<GatherBackward0>)
# tensor([[0.9664]], grad_fn=<GatherBackward0>)
# tensor([[1.5935]], grad_fn=<GatherBackward0>)
# tensor([[0.9653]], grad_fn=<GatherBackward0>)
# tensor([[1.6514]], grad_fn=<GatherBackward0>)
# tensor([[0.9604]], grad_fn=<GatherBackward0>)
# tensor([[1.6458]], grad_fn=<GatherBackward0>)
# tensor([[0.9634]], grad_fn=<GatherBackward0>)
# tensor([[1.6579]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6607]], grad_fn=<GatherBackward0>)
# tensor([[1.6484]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6542]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6515]], grad_fn=<GatherBackward0>)
# tensor([[0.9627]], grad_fn=<GatherBackward0>)
# tensor([[1.6157]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6516]], grad_fn=<GatherBackward0>)
# tensor([[0.9620]], grad_fn=<GatherBackward0>)
# tensor([[1.6525]], grad_fn=<GatherBackward0>)
# tensor([[0.9616]], grad_fn=<GatherBackward0>)
# tensor([[1.6534]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[2.7034]], grad_fn=<GatherBackward0>)
# tensor([[0.9636]], grad_fn=<GatherBackward0>)
# tensor([[2.5863]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.7128]], grad_fn=<GatherBackward0>)
# tensor([[0.9673]], grad_fn=<GatherBackward0>)
# tensor([[2.7205]], grad_fn=<GatherBackward0>)
# tensor([[0.9683]], grad_fn=<GatherBackward0>)
# tensor([[2.2738]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6373]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6591]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5379]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6212]], grad_fn=<GatherBackward0>)
# tensor([[0.9519]], grad_fn=<GatherBackward0>)
# tensor([[1.6359]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6068]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6090]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6622]], grad_fn=<GatherBackward0>)
# tensor([[2.6972]], grad_fn=<GatherBackward0>)
# tensor([[0.9704]], grad_fn=<GatherBackward0>)
# tensor([[1.6870]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.8257]], grad_fn=<GatherBackward0>)
# tensor([[0.9692]], grad_fn=<GatherBackward0>)
# tensor([[2.8028]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6584]], grad_fn=<GatherBackward0>)
# tensor([[0.9557]], grad_fn=<GatherBackward0>)
# tensor([[2.2169]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.0516]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6266]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6349]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6213]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8130]], grad_fn=<GatherBackward0>)
# tensor([[0.9664]], grad_fn=<GatherBackward0>)
# tensor([[2.7352]], grad_fn=<GatherBackward0>)
# tensor([[0.9711]], grad_fn=<GatherBackward0>)
# tensor([[1.6294]], grad_fn=<GatherBackward0>)
# tensor([[0.9735]], grad_fn=<GatherBackward0>)
# tensor([[1.6608]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6321]], grad_fn=<GatherBackward0>)
# tensor([[0.9737]], grad_fn=<GatherBackward0>)
# tensor([[2.8186]], grad_fn=<GatherBackward0>)
# tensor([[0.9779]], grad_fn=<GatherBackward0>)
# tensor([[2.8196]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8205]], grad_fn=<GatherBackward0>)
# tensor([[0.9798]], grad_fn=<GatherBackward0>)
# tensor([[1.5472]], grad_fn=<GatherBackward0>)
# tensor([[0.9595]], grad_fn=<GatherBackward0>)
# tensor([[2.6759]], grad_fn=<GatherBackward0>)
# tensor([[0.9593]], grad_fn=<GatherBackward0>)
# tensor([[1.6073]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6346]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6353]], grad_fn=<GatherBackward0>)
# tensor([[0.9706]], grad_fn=<GatherBackward0>)
# tensor([[1.6415]], grad_fn=<GatherBackward0>)
# tensor([[0.9677]], grad_fn=<GatherBackward0>)
# tensor([[1.6320]], grad_fn=<GatherBackward0>)
# tensor([[0.9625]], grad_fn=<GatherBackward0>)
# tensor([[1.6382]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6361]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6435]], grad_fn=<GatherBackward0>)
# tensor([[0.9620]], grad_fn=<GatherBackward0>)
# tensor([[1.6443]], grad_fn=<GatherBackward0>)
# tensor([[0.9617]], grad_fn=<GatherBackward0>)
# tensor([[1.6420]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6431]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.8323]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.2101]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6465]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6633]], grad_fn=<GatherBackward0>)
# tensor([[0.9414]], grad_fn=<GatherBackward0>)
# tensor([[1.6488]], grad_fn=<GatherBackward0>)
# tensor([[0.9822]], grad_fn=<GatherBackward0>)
# tensor([[1.6633]], grad_fn=<GatherBackward0>)
# tensor([[0.9591]], grad_fn=<GatherBackward0>)
# tensor([[1.6054]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6323]], grad_fn=<GatherBackward0>)
# tensor([[0.9827]], grad_fn=<GatherBackward0>)
# tensor([[1.6358]], grad_fn=<GatherBackward0>)
# tensor([[0.9798]], grad_fn=<GatherBackward0>)
# tensor([[1.5760]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6638]], grad_fn=<GatherBackward0>)
# tensor([[2.7638]], grad_fn=<GatherBackward0>)
# tensor([[0.9587]], grad_fn=<GatherBackward0>)
# tensor([[2.8152]], grad_fn=<GatherBackward0>)
# tensor([[0.9656]], grad_fn=<GatherBackward0>)
# tensor([[1.6489]], grad_fn=<GatherBackward0>)
# tensor([[0.9610]], grad_fn=<GatherBackward0>)
# tensor([[1.8018]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6413]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6411]], grad_fn=<GatherBackward0>)
# tensor([[2.5355]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6295]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6585]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6589]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6595]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6103]], grad_fn=<GatherBackward0>)
# tensor([[0.9584]], grad_fn=<GatherBackward0>)
# tensor([[1.6606]], grad_fn=<GatherBackward0>)
# tensor([[0.9676]], grad_fn=<GatherBackward0>)
# tensor([[1.6612]], grad_fn=<GatherBackward0>)
# tensor([[0.9334]], grad_fn=<GatherBackward0>)
# tensor([[1.6619]], grad_fn=<GatherBackward0>)
# tensor([[0.9722]], grad_fn=<GatherBackward0>)
# tensor([[1.6036]], grad_fn=<GatherBackward0>)
# tensor([[0.9595]], grad_fn=<GatherBackward0>)
# tensor([[1.6134]], grad_fn=<GatherBackward0>)
# tensor([[0.9737]], grad_fn=<GatherBackward0>)
# tensor([[1.5866]], grad_fn=<GatherBackward0>)
# tensor([[0.9730]], grad_fn=<GatherBackward0>)
# tensor([[1.6645]], grad_fn=<GatherBackward0>)
# tensor([[2.8270]], grad_fn=<GatherBackward0>)
# tensor([[0.9591]], grad_fn=<GatherBackward0>)
# tensor([[1.6167]], grad_fn=<GatherBackward0>)
# tensor([[0.9694]], grad_fn=<GatherBackward0>)
# tensor([[1.6394]], grad_fn=<GatherBackward0>)
# tensor([[0.9670]], grad_fn=<GatherBackward0>)
# tensor([[1.6184]], grad_fn=<GatherBackward0>)
# tensor([[0.9641]], grad_fn=<GatherBackward0>)
# tensor([[1.6502]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[1.5955]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6516]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6288]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6533]], grad_fn=<GatherBackward0>)
# tensor([[2.6834]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.1316]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.1499]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.9392]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.8173]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6161]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6080]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6416]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6420]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6133]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6132]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.9046]], grad_fn=<GatherBackward0>)
# tensor([[0.9633]], grad_fn=<GatherBackward0>)
# tensor([[2.5627]], grad_fn=<GatherBackward0>)
# tensor([[0.9384]], grad_fn=<GatherBackward0>)
# tensor([[1.6306]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6482]], grad_fn=<GatherBackward0>)
# tensor([[0.9701]], grad_fn=<GatherBackward0>)
# tensor([[1.6503]], grad_fn=<GatherBackward0>)
# tensor([[0.9712]], grad_fn=<GatherBackward0>)
# tensor([[2.2245]], grad_fn=<GatherBackward0>)
# tensor([[2.9034]], grad_fn=<GatherBackward0>)
# tensor([[0.9713]], grad_fn=<GatherBackward0>)
# tensor([[2.7642]], grad_fn=<GatherBackward0>)
# tensor([[0.9705]], grad_fn=<GatherBackward0>)
# tensor([[1.6263]], grad_fn=<GatherBackward0>)
# tensor([[0.9690]], grad_fn=<GatherBackward0>)
# tensor([[1.6271]], grad_fn=<GatherBackward0>)
# tensor([[0.9670]], grad_fn=<GatherBackward0>)
# tensor([[2.8676]], grad_fn=<GatherBackward0>)
# tensor([[0.9677]], grad_fn=<GatherBackward0>)
# tensor([[2.5597]], grad_fn=<GatherBackward0>)
# tensor([[0.9678]], grad_fn=<GatherBackward0>)
# tensor([[1.6377]], grad_fn=<GatherBackward0>)
# tensor([[0.9672]], grad_fn=<GatherBackward0>)
# tensor([[1.6386]], grad_fn=<GatherBackward0>)
# tensor([[0.9584]], grad_fn=<GatherBackward0>)
# tensor([[1.6397]], grad_fn=<GatherBackward0>)
# tensor([[0.9653]], grad_fn=<GatherBackward0>)
# tensor([[2.8184]], grad_fn=<GatherBackward0>)
# tensor([[0.9506]], grad_fn=<GatherBackward0>)
# tensor([[1.6422]], grad_fn=<GatherBackward0>)
# tensor([[0.9688]], grad_fn=<GatherBackward0>)
# tensor([[1.6436]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.5996]], grad_fn=<GatherBackward0>)
# tensor([[0.9703]], grad_fn=<GatherBackward0>)
# tensor([[1.6464]], grad_fn=<GatherBackward0>)
# tensor([[0.9597]], grad_fn=<GatherBackward0>)
# tensor([[1.6478]], grad_fn=<GatherBackward0>)
# tensor([[0.9701]], grad_fn=<GatherBackward0>)
# tensor([[1.6494]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6181]], grad_fn=<GatherBackward0>)
# tensor([[0.9685]], grad_fn=<GatherBackward0>)
# tensor([[2.3840]], grad_fn=<GatherBackward0>)
# tensor([[0.9702]], grad_fn=<GatherBackward0>)
# tensor([[2.2844]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6198]], grad_fn=<GatherBackward0>)
# tensor([[0.9717]], grad_fn=<GatherBackward0>)
# tensor([[1.6559]], grad_fn=<GatherBackward0>)
# tensor([[0.9714]], grad_fn=<GatherBackward0>)
# tensor([[1.6215]], grad_fn=<GatherBackward0>)
# tensor([[0.9703]], grad_fn=<GatherBackward0>)
# tensor([[1.6579]], grad_fn=<GatherBackward0>)
# tensor([[0.9685]], grad_fn=<GatherBackward0>)
# tensor([[1.6590]], grad_fn=<GatherBackward0>)
# tensor([[0.9612]], grad_fn=<GatherBackward0>)
# tensor([[1.6473]], grad_fn=<GatherBackward0>)
# tensor([[0.9614]], grad_fn=<GatherBackward0>)
# tensor([[1.6610]], grad_fn=<GatherBackward0>)
# tensor([[2.7753]], grad_fn=<GatherBackward0>)
# tensor([[0.9545]], grad_fn=<GatherBackward0>)
# tensor([[1.6386]], grad_fn=<GatherBackward0>)
# tensor([[0.9553]], grad_fn=<GatherBackward0>)
# tensor([[2.4577]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6624]], grad_fn=<GatherBackward0>)
# tensor([[0.9616]], grad_fn=<GatherBackward0>)
# tensor([[1.6648]], grad_fn=<GatherBackward0>)
# tensor([[0.9615]], grad_fn=<GatherBackward0>)
# tensor([[1.6670]], grad_fn=<GatherBackward0>)
# tensor([[0.9615]], grad_fn=<GatherBackward0>)
# tensor([[1.6244]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[1.6709]], grad_fn=<GatherBackward0>)
# tensor([[2.8428]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7004]], grad_fn=<GatherBackward0>)
# tensor([[0.9624]], grad_fn=<GatherBackward0>)
# tensor([[1.6705]], grad_fn=<GatherBackward0>)
# tensor([[0.9605]], grad_fn=<GatherBackward0>)
# tensor([[1.6731]], grad_fn=<GatherBackward0>)
# tensor([[0.9631]], grad_fn=<GatherBackward0>)
# tensor([[1.6755]], grad_fn=<GatherBackward0>)
# tensor([[0.9629]], grad_fn=<GatherBackward0>)
# tensor([[1.6287]], grad_fn=<GatherBackward0>)
# tensor([[0.9624]], grad_fn=<GatherBackward0>)
# tensor([[2.9406]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6316]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6827]], grad_fn=<GatherBackward0>)
# tensor([[0.9751]], grad_fn=<GatherBackward0>)
# tensor([[1.6840]], grad_fn=<GatherBackward0>)
# tensor([[0.9765]], grad_fn=<GatherBackward0>)
# tensor([[1.6311]], grad_fn=<GatherBackward0>)
# tensor([[0.9755]], grad_fn=<GatherBackward0>)
# tensor([[1.6292]], grad_fn=<GatherBackward0>)
# tensor([[0.9485]], grad_fn=<GatherBackward0>)
# tensor([[1.5015]], grad_fn=<GatherBackward0>)
# tensor([[2.8973]], grad_fn=<GatherBackward0>)
# tensor([[0.9586]], grad_fn=<GatherBackward0>)
# tensor([[1.8462]], grad_fn=<GatherBackward0>)
# tensor([[0.9674]], grad_fn=<GatherBackward0>)
# tensor([[2.5745]], grad_fn=<GatherBackward0>)
# tensor([[0.9593]], grad_fn=<GatherBackward0>)
# tensor([[1.6348]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[1.6900]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6902]], grad_fn=<GatherBackward0>)
# tensor([[0.9592]], grad_fn=<GatherBackward0>)
# tensor([[1.4766]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6904]], grad_fn=<GatherBackward0>)
# tensor([[0.9594]], grad_fn=<GatherBackward0>)
# tensor([[1.4757]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6342]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6901]], grad_fn=<GatherBackward0>)
# tensor([[0.9471]], grad_fn=<GatherBackward0>)
# tensor([[1.6496]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[1.6285]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6503]], grad_fn=<GatherBackward0>)
# tensor([[0.9605]], grad_fn=<GatherBackward0>)
# tensor([[1.6507]], grad_fn=<GatherBackward0>)
# tensor([[0.9605]], grad_fn=<GatherBackward0>)
# tensor([[1.6408]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6295]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6301]], grad_fn=<GatherBackward0>)
# tensor([[1.6424]], grad_fn=<GatherBackward0>)
# tensor([[0.9541]], grad_fn=<GatherBackward0>)
# tensor([[1.6885]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[1.6882]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6538]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6875]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6870]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6550]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6555]], grad_fn=<GatherBackward0>)
# tensor([[0.9507]], grad_fn=<GatherBackward0>)
# tensor([[1.4883]], grad_fn=<GatherBackward0>)
# tensor([[0.9574]], grad_fn=<GatherBackward0>)
# tensor([[1.5974]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6378]], grad_fn=<GatherBackward0>)
# tensor([[2.7809]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.5678]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6838]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6835]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6586]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6485]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6489]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6596]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6599]], grad_fn=<GatherBackward0>)
# tensor([[0.9604]], grad_fn=<GatherBackward0>)
# tensor([[1.6035]], grad_fn=<GatherBackward0>)
# tensor([[0.9608]], grad_fn=<GatherBackward0>)
# tensor([[1.6608]], grad_fn=<GatherBackward0>)
# tensor([[0.9611]], grad_fn=<GatherBackward0>)
# tensor([[1.6515]], grad_fn=<GatherBackward0>)
# tensor([[0.9608]], grad_fn=<GatherBackward0>)
# tensor([[1.6521]], grad_fn=<GatherBackward0>)
# tensor([[2.7746]], grad_fn=<GatherBackward0>)
# tensor([[0.9614]], grad_fn=<GatherBackward0>)
# tensor([[1.5763]], grad_fn=<GatherBackward0>)
# tensor([[0.9613]], grad_fn=<GatherBackward0>)
# tensor([[1.6804]], grad_fn=<GatherBackward0>)
# tensor([[0.9596]], grad_fn=<GatherBackward0>)
# tensor([[1.5972]], grad_fn=<GatherBackward0>)
# tensor([[0.9609]], grad_fn=<GatherBackward0>)
# tensor([[1.5880]], grad_fn=<GatherBackward0>)
# tensor([[0.9609]], grad_fn=<GatherBackward0>)
# tensor([[1.6799]], grad_fn=<GatherBackward0>)
# tensor([[0.9608]], grad_fn=<GatherBackward0>)
# tensor([[1.5843]], grad_fn=<GatherBackward0>)
# tensor([[0.9607]], grad_fn=<GatherBackward0>)
# tensor([[1.5866]], grad_fn=<GatherBackward0>)
# tensor([[2.6175]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[1.6792]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5068]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6069]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6786]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6784]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6782]], grad_fn=<GatherBackward0>)
# tensor([[2.7835]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6736]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6743]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6750]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.5981]], grad_fn=<GatherBackward0>)
# tensor([[0.9594]], grad_fn=<GatherBackward0>)
# tensor([[1.8992]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.7745]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.7932]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[2.6996]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6372]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5949]], grad_fn=<GatherBackward0>)
# tensor([[0.9592]], grad_fn=<GatherBackward0>)
# tensor([[1.5982]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6346]], grad_fn=<GatherBackward0>)
# tensor([[2.8145]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7117]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.7139]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7155]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.7166]], grad_fn=<GatherBackward0>)
# tensor([[2.8263]], grad_fn=<GatherBackward0>)
# tensor([[0.9598]], grad_fn=<GatherBackward0>)
# tensor([[1.9449]], grad_fn=<GatherBackward0>)
# tensor([[0.9598]], grad_fn=<GatherBackward0>)
# tensor([[2.7654]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5229]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[1.9417]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.4651]], grad_fn=<GatherBackward0>)
# tensor([[0.9595]], grad_fn=<GatherBackward0>)
# tensor([[1.6029]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8142]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.1076]], grad_fn=<GatherBackward0>)
# tensor([[0.9680]], grad_fn=<GatherBackward0>)
# tensor([[1.5913]], grad_fn=<GatherBackward0>)
# tensor([[0.9597]], grad_fn=<GatherBackward0>)
# tensor([[1.6874]], grad_fn=<GatherBackward0>)
# tensor([[0.9729]], grad_fn=<GatherBackward0>)
# tensor([[1.5908]], grad_fn=<GatherBackward0>)
# tensor([[0.9599]], grad_fn=<GatherBackward0>)
# tensor([[1.6849]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6838]], grad_fn=<GatherBackward0>)
# tensor([[0.9749]], grad_fn=<GatherBackward0>)
# tensor([[1.6827]], grad_fn=<GatherBackward0>)
# tensor([[2.8159]], grad_fn=<GatherBackward0>)
# tensor([[0.9739]], grad_fn=<GatherBackward0>)
# tensor([[2.1290]], grad_fn=<GatherBackward0>)
# tensor([[0.9715]], grad_fn=<GatherBackward0>)
# tensor([[1.6660]], grad_fn=<GatherBackward0>)
# tensor([[0.9682]], grad_fn=<GatherBackward0>)
# tensor([[1.6461]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6575]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.4971]], grad_fn=<GatherBackward0>)
# tensor([[0.9608]], grad_fn=<GatherBackward0>)
# tensor([[1.6509]], grad_fn=<GatherBackward0>)
# tensor([[0.9604]], grad_fn=<GatherBackward0>)
# tensor([[1.5951]], grad_fn=<GatherBackward0>)
# tensor([[0.9636]], grad_fn=<GatherBackward0>)
# tensor([[1.6165]], grad_fn=<GatherBackward0>)
# tensor([[0.9662]], grad_fn=<GatherBackward0>)
# tensor([[1.6437]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6420]], grad_fn=<GatherBackward0>)
# tensor([[0.9698]], grad_fn=<GatherBackward0>)
# tensor([[1.6407]], grad_fn=<GatherBackward0>)
# tensor([[0.9705]], grad_fn=<GatherBackward0>)
# tensor([[1.5019]], grad_fn=<GatherBackward0>)
# tensor([[0.9704]], grad_fn=<GatherBackward0>)
# tensor([[1.6038]], grad_fn=<GatherBackward0>)
# tensor([[0.9726]], grad_fn=<GatherBackward0>)
# tensor([[1.6382]], grad_fn=<GatherBackward0>)
# tensor([[0.9736]], grad_fn=<GatherBackward0>)
# tensor([[1.6378]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6059]], grad_fn=<GatherBackward0>)
# tensor([[0.9732]], grad_fn=<GatherBackward0>)
# tensor([[1.6050]], grad_fn=<GatherBackward0>)
# tensor([[0.9720]], grad_fn=<GatherBackward0>)
# tensor([[2.8401]], grad_fn=<GatherBackward0>)
# tensor([[0.9732]], grad_fn=<GatherBackward0>)
# tensor([[2.8401]], grad_fn=<GatherBackward0>)
# tensor([[0.9732]], grad_fn=<GatherBackward0>)
# tensor([[2.7147]], grad_fn=<GatherBackward0>)
# tensor([[0.9721]], grad_fn=<GatherBackward0>)
# tensor([[2.6062]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.5865]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.8456]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[2.3106]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6037]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6527]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6583]], grad_fn=<GatherBackward0>)
# tensor([[1.6060]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6584]], grad_fn=<GatherBackward0>)
# tensor([[0.9612]], grad_fn=<GatherBackward0>)
# tensor([[1.7889]], grad_fn=<GatherBackward0>)
# tensor([[0.9603]], grad_fn=<GatherBackward0>)
# tensor([[2.0850]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6275]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[2.3706]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8396]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7159]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8685]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.4455]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6424]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.2689]], grad_fn=<GatherBackward0>)
# tensor([[1.6402]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6602]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6472]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6607]], grad_fn=<GatherBackward0>)
# tensor([[0.9306]], grad_fn=<GatherBackward0>)
# tensor([[1.6610]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6614]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.0363]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.5042]], grad_fn=<GatherBackward0>)
# tensor([[0.9600]], grad_fn=<GatherBackward0>)
# tensor([[2.6839]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.0605]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7336]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6339]], grad_fn=<GatherBackward0>)
# tensor([[3.2305]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.6647]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.0399]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.8837]], grad_fn=<GatherBackward0>)
# tensor([[0.9516]], grad_fn=<GatherBackward0>)
# tensor([[2.4159]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.9672]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.4931]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[2.6164]], grad_fn=<GatherBackward0>)
# tensor([[0.9581]], grad_fn=<GatherBackward0>)
# tensor([[2.9289]], grad_fn=<GatherBackward0>)
# tensor([[0.9637]], grad_fn=<GatherBackward0>)
# tensor([[1.6997]], grad_fn=<GatherBackward0>)
# tensor([[0.9684]], grad_fn=<GatherBackward0>)
# tensor([[1.7004]], grad_fn=<GatherBackward0>)
# tensor([[0.9718]], grad_fn=<GatherBackward0>)
# tensor([[1.6766]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7013]], grad_fn=<GatherBackward0>)
# tensor([[0.9752]], grad_fn=<GatherBackward0>)
# tensor([[2.6761]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[3.1034]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.4519]], grad_fn=<GatherBackward0>)
# tensor([[0.9862]], grad_fn=<GatherBackward0>)
# tensor([[1.7019]], grad_fn=<GatherBackward0>)
# tensor([[0.9864]], grad_fn=<GatherBackward0>)
# tensor([[1.7018]], grad_fn=<GatherBackward0>)
# tensor([[0.9838]], grad_fn=<GatherBackward0>)
# tensor([[1.7014]], grad_fn=<GatherBackward0>)
# tensor([[0.9791]], grad_fn=<GatherBackward0>)
# tensor([[1.6784]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.7005]], grad_fn=<GatherBackward0>)
# tensor([[0.9751]], grad_fn=<GatherBackward0>)
# tensor([[1.6999]], grad_fn=<GatherBackward0>)
# tensor([[0.9718]], grad_fn=<GatherBackward0>)
# tensor([[1.6992]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6984]], grad_fn=<GatherBackward0>)
# tensor([[3.1154]], grad_fn=<GatherBackward0>)
# tensor([[0.9639]], grad_fn=<GatherBackward0>)
# tensor([[1.6871]], grad_fn=<GatherBackward0>)
# tensor([[0.9602]], grad_fn=<GatherBackward0>)
# tensor([[1.6093]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6789]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5542]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5555]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6789]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6141]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5803]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6593]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6127]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6555]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.4590]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6527]], grad_fn=<GatherBackward0>)
# tensor([[2.9792]], grad_fn=<GatherBackward0>)
# tensor([[0.9519]], grad_fn=<GatherBackward0>)
# tensor([[2.5209]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6166]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.4678]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6783]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6783]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6781]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6780]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6160]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6217]], grad_fn=<GatherBackward0>)
# tensor([[0.9299]], grad_fn=<GatherBackward0>)
# tensor([[1.6124]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6236]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6248]], grad_fn=<GatherBackward0>)
# tensor([[2.6548]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6628]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.6769]], grad_fn=<GatherBackward0>)
# tensor([[0.9601]], grad_fn=<GatherBackward0>)
# tensor([[1.5803]], grad_fn=<GatherBackward0>)
# ...
# tensor([[1.5981]], grad_fn=<GatherBackward0>)
# tensor([[1.0023]], grad_fn=<GatherBackward0>)
# tensor([[1.6012]], grad_fn=<GatherBackward0>)
# tensor([[1.0048]], grad_fn=<GatherBackward0>)
# tensor([[1.6022]], grad_fn=<GatherBackward0>)
# tensor([[0.9693]], grad_fn=<GatherBackward0>)
# tensor([[1.5854]], grad_fn=<GatherBackward0>)
# tensor([[0.9795]], grad_fn=<GatherBackward0>)
# tensor([[1.5732]], grad_fn=<GatherBackward0>)
# tensor([[0.9934]], grad_fn=<GatherBackward0>)
# tensor([[2.6724]], grad_fn=<GatherBackward0>)
# tensor([[0.9922]], grad_fn=<GatherBackward0>)
# tensor([[2.9592]], grad_fn=<GatherBackward0>)
# tensor([[0.9882]], grad_fn=<GatherBackward0>)
# tensor([[1.5754]], grad_fn=<GatherBackward0>)
# tensor([[0.9829]], grad_fn=<GatherBackward0>)
# tensor([[1.6076]], grad_fn=<GatherBackward0>)
# tensor([[0.9787]], grad_fn=<GatherBackward0>)
# tensor([[1.6084]], grad_fn=<GatherBackward0>)
# tensor([[0.9816]], grad_fn=<GatherBackward0>)
# tensor([[1.5200]], grad_fn=<GatherBackward0>)
# tensor([[0.9800]], grad_fn=<GatherBackward0>)
# tensor([[1.5083]], grad_fn=<GatherBackward0>)
# tensor([[0.9842]], grad_fn=<GatherBackward0>)
# tensor([[1.6109]], grad_fn=<GatherBackward0>)
# tensor([[0.9850]], grad_fn=<GatherBackward0>)
# tensor([[1.6118]], grad_fn=<GatherBackward0>)
# tensor([[2.9613]], grad_fn=<GatherBackward0>)
# tensor([[0.9848]], grad_fn=<GatherBackward0>)
# tensor([[2.9600]], grad_fn=<GatherBackward0>)
# tensor([[0.9564]], grad_fn=<GatherBackward0>)
# tensor([[1.5976]], grad_fn=<GatherBackward0>)
# tensor([[0.9812]], grad_fn=<GatherBackward0>)
# tensor([[1.5149]], grad_fn=<GatherBackward0>)
# tensor([[0.9831]], grad_fn=<GatherBackward0>)
# tensor([[1.5211]], grad_fn=<GatherBackward0>)
# tensor([[0.9830]], grad_fn=<GatherBackward0>)
# tensor([[1.6014]], grad_fn=<GatherBackward0>)
# tensor([[0.9723]], grad_fn=<GatherBackward0>)
# tensor([[1.6027]], grad_fn=<GatherBackward0>)
# tensor([[0.9823]], grad_fn=<GatherBackward0>)
# tensor([[1.5654]], grad_fn=<GatherBackward0>)
# tensor([[0.9831]], grad_fn=<GatherBackward0>)
# tensor([[1.6055]], grad_fn=<GatherBackward0>)
# tensor([[2.3773]], grad_fn=<GatherBackward0>)
# tensor([[0.9873]], grad_fn=<GatherBackward0>)
# tensor([[2.9467]], grad_fn=<GatherBackward0>)
# tensor([[0.9897]], grad_fn=<GatherBackward0>)
# tensor([[1.5889]], grad_fn=<GatherBackward0>)
# tensor([[0.9897]], grad_fn=<GatherBackward0>)
# tensor([[1.5280]], grad_fn=<GatherBackward0>)
# tensor([[0.9875]], grad_fn=<GatherBackward0>)
# tensor([[2.9483]], grad_fn=<GatherBackward0>)
# tensor([[0.9803]], grad_fn=<GatherBackward0>)
# tensor([[2.9482]], grad_fn=<GatherBackward0>)
# tensor([[0.9903]], grad_fn=<GatherBackward0>)
# tensor([[1.5751]], grad_fn=<GatherBackward0>)
# tensor([[0.9892]], grad_fn=<GatherBackward0>)
# tensor([[1.5979]], grad_fn=<GatherBackward0>)
# tensor([[0.9862]], grad_fn=<GatherBackward0>)
# tensor([[1.5346]], grad_fn=<GatherBackward0>)
# tensor([[0.9831]], grad_fn=<GatherBackward0>)
# tensor([[1.6041]], grad_fn=<GatherBackward0>)
# tensor([[0.9829]], grad_fn=<GatherBackward0>)
# tensor([[1.5709]], grad_fn=<GatherBackward0>)
# tensor([[0.9824]], grad_fn=<GatherBackward0>)
# tensor([[1.6096]], grad_fn=<GatherBackward0>)
# tensor([[0.9819]], grad_fn=<GatherBackward0>)
# tensor([[1.6121]], grad_fn=<GatherBackward0>)
# tensor([[2.9447]], grad_fn=<GatherBackward0>)
# tensor([[0.9750]], grad_fn=<GatherBackward0>)
# tensor([[2.9442]], grad_fn=<GatherBackward0>)
# tensor([[0.9811]], grad_fn=<GatherBackward0>)
# tensor([[1.5981]], grad_fn=<GatherBackward0>)
# tensor([[0.9792]], grad_fn=<GatherBackward0>)
# tensor([[1.5740]], grad_fn=<GatherBackward0>)
# tensor([[0.9809]], grad_fn=<GatherBackward0>)
# tensor([[1.5916]], grad_fn=<GatherBackward0>)
# tensor([[0.9819]], grad_fn=<GatherBackward0>)
# tensor([[1.5892]], grad_fn=<GatherBackward0>)
# tensor([[0.9810]], grad_fn=<GatherBackward0>)
# tensor([[1.5735]], grad_fn=<GatherBackward0>)
# tensor([[0.9844]], grad_fn=<GatherBackward0>)
# tensor([[1.5859]], grad_fn=<GatherBackward0>)
# tensor([[0.9577]], grad_fn=<GatherBackward0>)
# tensor([[1.5781]], grad_fn=<GatherBackward0>)
# tensor([[0.9630]], grad_fn=<GatherBackward0>)
# tensor([[1.5792]], grad_fn=<GatherBackward0>)
# tensor([[0.9800]], grad_fn=<GatherBackward0>)
# tensor([[1.5808]], grad_fn=<GatherBackward0>)
# tensor([[0.9854]], grad_fn=<GatherBackward0>)
# tensor([[2.9412]], grad_fn=<GatherBackward0>)
# tensor([[0.9832]], grad_fn=<GatherBackward0>)
# tensor([[2.9411]], grad_fn=<GatherBackward0>)
# tensor([[0.9943]], grad_fn=<GatherBackward0>)
# tensor([[2.9411]], grad_fn=<GatherBackward0>)
# tensor([[0.9994]], grad_fn=<GatherBackward0>)
# tensor([[2.8071]], grad_fn=<GatherBackward0>)
# tensor([[1.5890]], grad_fn=<GatherBackward0>)
# tensor([[0.9830]], grad_fn=<GatherBackward0>)
# tensor([[1.5911]], grad_fn=<GatherBackward0>)
# tensor([[1.0021]], grad_fn=<GatherBackward0>)
# tensor([[1.5934]], grad_fn=<GatherBackward0>)
# tensor([[0.9818]], grad_fn=<GatherBackward0>)
# tensor([[1.5958]], grad_fn=<GatherBackward0>)
# tensor([[1.8468]], grad_fn=<GatherBackward0>)
# tensor([[0.9942]], grad_fn=<GatherBackward0>)
# tensor([[1.5351]], grad_fn=<GatherBackward0>)
# tensor([[0.9802]], grad_fn=<GatherBackward0>)
# tensor([[1.6004]], grad_fn=<GatherBackward0>)
# tensor([[0.9910]], grad_fn=<GatherBackward0>)
# tensor([[1.5529]], grad_fn=<GatherBackward0>)
# tensor([[0.9504]], grad_fn=<GatherBackward0>)
# tensor([[1.6200]], grad_fn=<GatherBackward0>)
# tensor([[0.9832]], grad_fn=<GatherBackward0>)
# tensor([[1.5554]], grad_fn=<GatherBackward0>)
# tensor([[0.9825]], grad_fn=<GatherBackward0>)
# tensor([[1.6360]], grad_fn=<GatherBackward0>)
# tensor([[1.6356]], grad_fn=<GatherBackward0>)
# tensor([[0.9825]], grad_fn=<GatherBackward0>)
# tensor([[1.5654]], grad_fn=<GatherBackward0>)
# tensor([[0.9823]], grad_fn=<GatherBackward0>)
# tensor([[1.5477]], grad_fn=<GatherBackward0>)
# tensor([[0.9835]], grad_fn=<GatherBackward0>)
# tensor([[1.5496]], grad_fn=<GatherBackward0>)
# tensor([[0.9878]], grad_fn=<GatherBackward0>)
# tensor([[1.6768]], grad_fn=<GatherBackward0>)
# tensor([[0.9664]], grad_fn=<GatherBackward0>)
# tensor([[1.6842]], grad_fn=<GatherBackward0>)
# tensor([[0.9821]], grad_fn=<GatherBackward0>)
# tensor([[1.6902]], grad_fn=<GatherBackward0>)
# tensor([[0.9824]], grad_fn=<GatherBackward0>)
# tensor([[1.6949]], grad_fn=<GatherBackward0>)
# tensor([[0.9824]], grad_fn=<GatherBackward0>)
# tensor([[1.5605]], grad_fn=<GatherBackward0>)
# tensor([[0.9975]], grad_fn=<GatherBackward0>)
# tensor([[1.5619]], grad_fn=<GatherBackward0>)
# tensor([[0.9822]], grad_fn=<GatherBackward0>)
# tensor([[1.5625]], grad_fn=<GatherBackward0>)
# tensor([[0.9821]], grad_fn=<GatherBackward0>)
# tensor([[1.7072]], grad_fn=<GatherBackward0>)
# tensor([[0.9802]], grad_fn=<GatherBackward0>)
# tensor([[1.7203]], grad_fn=<GatherBackward0>)
# tensor([[0.9884]], grad_fn=<GatherBackward0>)
# tensor([[1.7354]], grad_fn=<GatherBackward0>)
# tensor([[0.9615]], grad_fn=<GatherBackward0>)
# tensor([[1.7531]], grad_fn=<GatherBackward0>)
# tensor([[1.7615]], grad_fn=<GatherBackward0>)
# tensor([[0.9911]], grad_fn=<GatherBackward0>)
# tensor([[1.7784]], grad_fn=<GatherBackward0>)
# tensor([[0.9821]], grad_fn=<GatherBackward0>)
# tensor([[1.5742]], grad_fn=<GatherBackward0>)
# tensor([[0.9767]], grad_fn=<GatherBackward0>)
# tensor([[1.5553]], grad_fn=<GatherBackward0>)
# tensor([[0.9895]], grad_fn=<GatherBackward0>)
# tensor([[1.8423]], grad_fn=<GatherBackward0>)
# tensor([[0.9876]], grad_fn=<GatherBackward0>)
# tensor([[1.8577]], grad_fn=<GatherBackward0>)
# tensor([[0.9848]], grad_fn=<GatherBackward0>)
# tensor([[1.8695]], grad_fn=<GatherBackward0>)
# tensor([[0.9910]], grad_fn=<GatherBackward0>)
# tensor([[1.5493]], grad_fn=<GatherBackward0>)
# tensor([[0.9910]], grad_fn=<GatherBackward0>)
# tensor([[1.9042]], grad_fn=<GatherBackward0>)
# tensor([[0.9882]], grad_fn=<GatherBackward0>)
# tensor([[1.4502]], grad_fn=<GatherBackward0>)
# tensor([[0.9861]], grad_fn=<GatherBackward0>)
# tensor([[1.9280]], grad_fn=<GatherBackward0>)
# tensor([[0.9798]], grad_fn=<GatherBackward0>)
# tensor([[1.5589]], grad_fn=<GatherBackward0>)
# tensor([[0.9861]], grad_fn=<GatherBackward0>)
# tensor([[1.9424]], grad_fn=<GatherBackward0>)
# tensor([[0.9846]], grad_fn=<GatherBackward0>)
# tensor([[1.9460]], grad_fn=<GatherBackward0>)
# tensor([[0.9833]], grad_fn=<GatherBackward0>)
# tensor([[1.9466]], grad_fn=<GatherBackward0>)
# tensor([[0.9883]], grad_fn=<GatherBackward0>)
# tensor([[1.9445]], grad_fn=<GatherBackward0>)
# tensor([[2.9086]], grad_fn=<GatherBackward0>)
# tensor([[0.9880]], grad_fn=<GatherBackward0>)
# tensor([[1.9268]], grad_fn=<GatherBackward0>)
# tensor([[0.9798]], grad_fn=<GatherBackward0>)
# tensor([[1.9177]], grad_fn=<GatherBackward0>)
# tensor([[0.9846]], grad_fn=<GatherBackward0>)
# tensor([[1.9071]], grad_fn=<GatherBackward0>)
# tensor([[0.9723]], grad_fn=<GatherBackward0>)
# tensor([[1.8954]], grad_fn=<GatherBackward0>)
# tensor([[1.8783]], grad_fn=<GatherBackward0>)
# tensor([[0.9831]], grad_fn=<GatherBackward0>)
# tensor([[1.8704]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[1.5700]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[1.8538]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[1.6615]], grad_fn=<GatherBackward0>)
# tensor([[0.9822]], grad_fn=<GatherBackward0>)
# tensor([[1.5731]], grad_fn=<GatherBackward0>)
# tensor([[0.9832]], grad_fn=<GatherBackward0>)
# tensor([[1.6625]], grad_fn=<GatherBackward0>)
# tensor([[0.9841]], grad_fn=<GatherBackward0>)
# tensor([[1.6625]], grad_fn=<GatherBackward0>)
# tensor([[0.9774]], grad_fn=<GatherBackward0>)
# tensor([[1.5574]], grad_fn=<GatherBackward0>)
# tensor([[0.9845]], grad_fn=<GatherBackward0>)
# tensor([[1.5785]], grad_fn=<GatherBackward0>)
# tensor([[0.9828]], grad_fn=<GatherBackward0>)
# tensor([[1.5791]], grad_fn=<GatherBackward0>)
# tensor([[0.9827]], grad_fn=<GatherBackward0>)
# tensor([[1.5802]], grad_fn=<GatherBackward0>)
# tensor([[1.7999]], grad_fn=<GatherBackward0>)
# tensor([[0.9831]], grad_fn=<GatherBackward0>)
# tensor([[1.8042]], grad_fn=<GatherBackward0>)
# tensor([[0.9824]], grad_fn=<GatherBackward0>)
# tensor([[1.5616]], grad_fn=<GatherBackward0>)
# tensor([[0.9708]], grad_fn=<GatherBackward0>)
# tensor([[1.8180]], grad_fn=<GatherBackward0>)
# tensor([[0.9819]], grad_fn=<GatherBackward0>)
# tensor([[1.8225]], grad_fn=<GatherBackward0>)
# tensor([[0.9819]], grad_fn=<GatherBackward0>)
# tensor([[1.6597]], grad_fn=<GatherBackward0>)
# tensor([[0.9814]], grad_fn=<GatherBackward0>)
# tensor([[1.6591]], grad_fn=<GatherBackward0>)
# tensor([[0.9818]], grad_fn=<GatherBackward0>)
# tensor([[1.6582]], grad_fn=<GatherBackward0>)
# tensor([[0.9828]], grad_fn=<GatherBackward0>)
# tensor([[1.6570]], grad_fn=<GatherBackward0>)
# tensor([[1.8333]], grad_fn=<GatherBackward0>)
# tensor([[0.9824]], grad_fn=<GatherBackward0>)
# tensor([[1.8419]], grad_fn=<GatherBackward0>)
# tensor([[0.9808]], grad_fn=<GatherBackward0>)
# tensor([[1.8564]], grad_fn=<GatherBackward0>)
# tensor([[0.9806]], grad_fn=<GatherBackward0>)
# tensor([[1.8679]], grad_fn=<GatherBackward0>)
# tensor([[1.8721]], grad_fn=<GatherBackward0>)
# tensor([[0.9879]], grad_fn=<GatherBackward0>)
# tensor([[1.8823]], grad_fn=<GatherBackward0>)
# tensor([[0.9870]], grad_fn=<GatherBackward0>)
# tensor([[1.8908]], grad_fn=<GatherBackward0>)
# tensor([[0.9769]], grad_fn=<GatherBackward0>)
# tensor([[1.8968]], grad_fn=<GatherBackward0>)
# tensor([[1.8962]], grad_fn=<GatherBackward0>)
# tensor([[0.9817]], grad_fn=<GatherBackward0>)
# tensor([[1.6003]], grad_fn=<GatherBackward0>)
# tensor([[0.9791]], grad_fn=<GatherBackward0>)
# tensor([[1.4682]], grad_fn=<GatherBackward0>)
# tensor([[0.9834]], grad_fn=<GatherBackward0>)
# tensor([[1.4745]], grad_fn=<GatherBackward0>)
# tensor([[0.9832]], grad_fn=<GatherBackward0>)
# tensor([[1.4834]], grad_fn=<GatherBackward0>)
# tensor([[0.9836]], grad_fn=<GatherBackward0>)
# tensor([[1.9189]], grad_fn=<GatherBackward0>)
# tensor([[0.9818]], grad_fn=<GatherBackward0>)
# tensor([[1.9216]], grad_fn=<GatherBackward0>)
# tensor([[0.9818]], grad_fn=<GatherBackward0>)
# tensor([[1.5302]], grad_fn=<GatherBackward0>)
# tensor([[0.9856]], grad_fn=<GatherBackward0>)
# tensor([[1.9225]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[1.9210]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[1.6085]], grad_fn=<GatherBackward0>)
# tensor([[0.9844]], grad_fn=<GatherBackward0>)
# tensor([[1.5873]], grad_fn=<GatherBackward0>)
# tensor([[0.9834]], grad_fn=<GatherBackward0>)
# tensor([[2.1455]], grad_fn=<GatherBackward0>)
# tensor([[0.9820]], grad_fn=<GatherBackward0>)
# tensor([[11.3763]], grad_fn=<GatherBackward0>)
# tensor([[0.9691]], grad_fn=<GatherBackward0>)
# tensor([[8.0088]], grad_fn=<GatherBackward0>)
# tensor([[0.9826]], grad_fn=<GatherBackward0>)
# tensor([[4.1600]], grad_fn=<GatherBackward0>)
# tensor([[0.9743]], grad_fn=<GatherBackward0>)
# tensor([[21.2031]], grad_fn=<GatherBackward0>)
# tensor([[0.9818]], grad_fn=<GatherBackward0>)
# tensor([[8.4954]], grad_fn=<GatherBackward0>)
# tensor([[0.9775]], grad_fn=<GatherBackward0>)
# tensor([[1.7035]], grad_fn=<GatherBackward0>)
# tensor([[0.9819]], grad_fn=<GatherBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c6ef38c6a0d3> in <cell line: 135>()
#     133
#     134 # Train the agents
# --> 135 agent1, agent2 = train(num_episodes)
#     136 agent1.save(savePath + "agent1.pth")
#     137 agent2.save(savePath + "agent2.pth")
#
# <ipython-input-7-c6ef38c6a0d3> in train(num_episodes)
#     114
#     115             if turn == 0:
# --> 116                 agent1.update(board, action, reward, next_state, game_over)
#     117             else:
#     118                 agent2.update(board, action, -reward, next_state, game_over)
#
# <ipython-input-7-c6ef38c6a0d3> in update(self, state, action, reward, next_state, done)
#      47
#      48         q_value = q_values.gather(1, action_tensor.unsqueeze(1))
# ---> 49         print(q_value)
#      50         next_q_value = next_q_values.max(1)[0].unsqueeze(1)
#      51         expected_q_value = reward_tensor + (1 - done) * self.gamma * next_q_value
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in __repr__(self, tensor_contents)
#     462             )
#     463         # All strings are unicode in Python 3.
# --> 464         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     465
#     466     def backward(
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor_str.py in _str(self, tensor_contents)
#     695     with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     696         guard = torch._C._DisableFuncTorch()
# --> 697         return _str_intern(self, tensor_contents=tensor_contents)
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor_str.py in _str_intern(inp, tensor_contents)
#     615                         tensor_str = _tensor_str(self.to_dense(), indent)
#     616                     else:
# --> 617                         tensor_str = _tensor_str(self, indent)
#     618
#     619     if self.layout != torch.strided:
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     347         )
#     348     else:
# --> 349         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     350         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     351
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor_str.py in __init__(self, tensor)
#     126         self.max_width = 1
#     127
# --> 128         with torch.no_grad():
#     129             tensor_view = tensor.reshape(-1)
#     130
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py in __enter__(self)
#      79     def __enter__(self) -> None:
#      80         self.prev = torch.is_grad_enabled()
# ---> 81         torch.set_grad_enabled(False)
#      82
#      83     def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py in __init__(self, mode)
#     182
#     183     def __init__(self, mode: bool) -> None:
# --> 184         self.prev = torch.is_grad_enabled()
#     185         self.mode = mode
#     186         torch._C._set_grad_enabled(mode)
#
# KeyboardInterrupt:

# %% [markdown]
# ##Train

# %% [markdown]
# ##Evaluation

# %% [markdown]
# ##Player v Computer
